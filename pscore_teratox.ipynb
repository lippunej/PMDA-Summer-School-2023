# %%
import pandas as pd
import numpy as np
import scipy as sp

# %%
teratox_commercial_feature = pd.read_csv('data/2022-02-18-TeraTox-commercial-featureData.txt', sep="\t")
teratox_commercial_feature.head()
# Out:
#   Unnamed: 0 FeatureName Transcript      Amplicon  GeneID GeneSymbol  \
# 0    SULT1C2   NM_176825  NM_176825  AMPL17111663    6819    SULT1C2
# 1     CYP1B1   NM_000104  NM_000104   AMPL1643513    1545     CYP1B1
# 2       RARB   NM_000965  NM_000965   AMPL3877085    5915       RARB
# 3      TREX1   NM_016381  NM_016381  AMPL31797718   11277      TREX1
# 4       HOPX   NM_139211  NM_139211  AMPL34269818   84525       HOPX
#
#    AmpliconSize  IsGeneCard
# 0           106       False
# 1           110       False
# 2           108       False
# 3           109       False
# 4           108        True

# %%
teratox_commercial_phenodata = pd.read_csv('data/2022-02-18-TeraTox-commercial-phenoData.txt', sep="\t")
teratox_commercial_phenodata.head()
# Out:
#           Unnamed: 0           Contrast Compound_Name  Concentration  \
# 0  Amoxicillin_DoseA  Amoxicillin_DoseA   Amoxycillin       0.000200
# 1  Amoxicillin_DoseB  Amoxicillin_DoseB   Amoxycillin       0.000100
# 2  Amoxicillin_DoseC  Amoxicillin_DoseC   Amoxycillin       0.000050
# 3  Amoxicillin_DoseD  Amoxicillin_DoseD   Amoxycillin       0.000025
# 4  Amoxicillin_DoseE  Amoxicillin_DoseE   Amoxycillin       0.000013
#
#    ConcLabel  Viability  Cytotoxicity Teratogenicity      mEST
# 0          6   0.905376      0.094624       Negative  Negative
# 1          5   0.977817      0.022183       Negative  Negative
# 2          4   0.912548      0.087452       Negative  Negative
# 3          3   0.906648      0.093352       Negative  Negative
# 4          2   0.975004      0.024996       Negative  Negative

# %%
gcGeneFactorAnno_withPositiveCoefs = pd.read_csv('data/2021-06-10-gcGeneFactorAnno-withPositiveCoefs.tsv', sep="\t")
gcGeneFactorAnno_withPositiveCoefs.head()
# Out:
#   GeneSymbol            Factor FeatureName  GeneID  \
# 0       WNT1  Factor1/Ectoderm        WNT1    7471
# 1     POU4F1  Factor1/Ectoderm      POU4F1    5457
# 2      OLFM3  Factor1/Ectoderm       OLFM3  118427
# 3       CDH9  Factor1/Ectoderm        CDH9    1007
# 4      LMX1A  Factor1/Ectoderm       LMX1A    4009
#
#                                     GeneName FeatureClass    avgCpm
# 0                        Wnt family member 1     Ectoderm  7.661111
# 1                     POU class 4 homeobox 1     Ectoderm  5.868008
# 2                             olfactomedin 3     Ectoderm  7.847020
# 3                                 cadherin 9     Ectoderm  8.589961
# 4  LIM homeobox transcription factor 1 alpha     Ectoderm  8.473594

# %%
teratox_commercial_logfc = pd.read_csv('data/2022-02-18-TeraTox-commercial-logFC.gct',sep="\t")
teratox_commercial_logfc.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
teratox_commercial_pscore = pd.read_csv('data/2022-02-18-TeraTox-commercial-pScore.gct',sep="\t")
teratox_commercial_pscore.head()
# Out:
#       NAME  Unnamed: 1  Amoxicillin_DoseA  Amoxicillin_DoseB  \
# 0  SULT1C2         NaN          -2.442982          -3.076067
# 1   CYP1B1         NaN           2.425835           2.263778
# 2     RARB         NaN           2.388456           1.888911
# 3    TREX1         NaN           2.355938           0.327302
# 4     HOPX         NaN           2.275017           1.897811
#
#    Amoxicillin_DoseC  Amoxicillin_DoseD  Amoxicillin_DoseE  Amoxicillin_DoseF  \
# 0          -2.912107          -1.744866          -4.697604          -4.076795
# 1           3.040933           3.713941           2.314085          -1.578264
# 2           2.547681           2.584569           0.997007          -0.062048
# 3           1.199058           0.420275           1.011521           3.069499
# 4           2.227049           3.142554           1.340227          -0.173469
#
#    Artesunate_DoseA  Artesunate_DoseB  ...  SD_Misoprostol_3  \
# 0         -3.491647         -5.351505  ...         -1.463613
# ...

# %%
# teratox_commercial_phenodata_below_cyto = teratox_commercial_phenodata.loc[teratox_commercial_phenodata.groupby(teratox_commercial_phenodata.index//6)]
# # .Cytotoxicity[teratox_commercial_phenodata['Cytotoxicity'] <= 0.2].idxmax(), :]
# # teratox_commercial_phenodata.loc[(teratox_commercial_phenodata['Cytotoxicity'] <= 0.2)]
# teratox_commercial_phenodata_below_cyto

# %%
len(teratox_commercial_phenodata["Compound_Name"].unique())
# Out:
# 33

# %%
teratox_commercial_phenodata_below_cyto = teratox_commercial_phenodata[teratox_commercial_phenodata['Cytotoxicity']<0.2]
len(teratox_commercial_phenodata_below_cyto["Compound_Name"].unique())
# Out:
# 32

# %%
# print(len(teratox_commercial_phenodata["Compound_Name"].unique()))
# print(len(teratox_commercial_phenodata_below_cyto["Compound_Name"].unique()))

# %%
teratox_commercial_phenodata_below_cyto = teratox_commercial_phenodata_below_cyto.loc[teratox_commercial_phenodata_below_cyto.groupby(teratox_commercial_phenodata_below_cyto.index//6).Cytotoxicity.idxmax(), :]
teratox_commercial_phenodata_below_cyto = teratox_commercial_phenodata_below_cyto.append(teratox_commercial_phenodata.loc[teratox_commercial_phenodata['Contrast']=='Thalidomide_DoseF'])

# %%
len(teratox_commercial_phenodata_below_cyto["Compound_Name"].unique())
# Out:
# 33

# %%
teratox_commercial_phenodata_below_cyto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 5 to 161
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      36 non-null     object
#  1   Contrast        36 non-null     object
#  2   Compound_Name   36 non-null     object
#  3   Concentration   36 non-null     float64
#  4   ConcLabel       36 non-null     int64
#  5   Viability       36 non-null     float64
#  6   Cytotoxicity    36 non-null     float64
#  7   Teratogenicity  36 non-null     object
#  8   mEST            36 non-null     object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 2.8+ KB

# %%
teratox_commercial_phenodata_below_cyto.reset_index()
# Out:
#     index            Unnamed: 0              Contrast   Compound_Name  \
# 0       5     Amoxicillin_DoseF     Amoxicillin_DoseF     Amoxycillin
# 1       9      Artesunate_DoseD      Artesunate_DoseD      Artesunate
# 2      17   Ascorbic.Acid_DoseF   Ascorbic.Acid_DoseF   Ascorbic acid
# 3      19        Bosentan_DoseB        Bosentan_DoseB        Bosentan
# 4      27        Busulfan_DoseD        Busulfan_DoseD        Busulfan
# 5      32   Carbamazepine_DoseC   Carbamazepine_DoseC   Carbamazepine
# 6      39      Cetirizine_DoseD      Cetirizine_DoseD      Cetirizine
# 7      42     Cyclopamine_DoseA     Cyclopamine_DoseA     Cyclopamine
# 8      51  Cyproheptadine_DoseD  Cyproheptadine_DoseD  Cyproheptadine
# 9      57      Dabrafenib_DoseD      Dabrafenib_DoseD      Dabrafenib
# 10     64            DAPT_DoseE            DAPT_DoseE            DAPT
# 11     67       Dasatinib_DoseB       Dasatinib_DoseB       Dasatinib
# ...

# %%
teratox_commercial_phenodata_below_cyto_withoutSD = teratox_commercial_phenodata_below_cyto.drop([teratox_commercial_phenodata_below_cyto.index[29],teratox_commercial_phenodata_below_cyto.index[30],teratox_commercial_phenodata_below_cyto.index[31]])
teratox_commercial_phenodata_below_cyto_withoutSD
# Out:
#                Unnamed: 0              Contrast   Compound_Name  \
# 5       Amoxicillin_DoseF     Amoxicillin_DoseF     Amoxycillin
# 9        Artesunate_DoseD      Artesunate_DoseD      Artesunate
# 17    Ascorbic.Acid_DoseF   Ascorbic.Acid_DoseF   Ascorbic acid
# 19         Bosentan_DoseB        Bosentan_DoseB        Bosentan
# 27         Busulfan_DoseD        Busulfan_DoseD        Busulfan
# 32    Carbamazepine_DoseC   Carbamazepine_DoseC   Carbamazepine
# 39       Cetirizine_DoseD      Cetirizine_DoseD      Cetirizine
# 42      Cyclopamine_DoseA     Cyclopamine_DoseA     Cyclopamine
# 51   Cyproheptadine_DoseD  Cyproheptadine_DoseD  Cyproheptadine
# 57       Dabrafenib_DoseD      Dabrafenib_DoseD      Dabrafenib
# 64             DAPT_DoseE            DAPT_DoseE            DAPT
# 67        Dasatinib_DoseB       Dasatinib_DoseB       Dasatinib
# 72    Dexamethasone_DoseA   Dexamethasone_DoseA   Dexamethasone
# 79     Dorsomorphin_DoseB    Dorsomorphin_DoseB    Dorsomorphin
# ...

# %%
len(teratox_commercial_phenodata_below_cyto_withoutSD["Contrast"])
# Out:
# 33

# %%
teratox_commercial_pscore
# Out:
#          NAME  Unnamed: 1  Amoxicillin_DoseA  Amoxicillin_DoseB  \
# 0     SULT1C2         NaN          -2.442982          -3.076067
# 1      CYP1B1         NaN           2.425835           2.263778
# 2        RARB         NaN           2.388456           1.888911
# 3       TREX1         NaN           2.355938           0.327302
# 4        HOPX         NaN           2.275017           1.897811
# ...       ...         ...                ...                ...
# 1210    TRPM8         NaN          -0.003516          -0.056941
# 1211    SCN4A         NaN           0.003240          -0.303338
# 1212   CYP7B1         NaN           0.000684          -0.090938
# 1213    GSTP1         NaN          -0.000145          -0.172979
# 1214    ACACA         NaN           0.000000          -0.202717
#
#       Amoxicillin_DoseC  Amoxicillin_DoseD  Amoxicillin_DoseE  \
# 0             -2.912107          -1.744866          -4.697604
# 1              3.040933           3.713941           2.314085
# ...

# %%
teratox_commercial_pscore_per_drug_dose = teratox_commercial_pscore[teratox_commercial_phenodata_below_cyto_withoutSD["Contrast"]]
teratox_commercial_pscore_per_drug_dose
# Out:
#       Amoxicillin_DoseF  Artesunate_DoseD  Ascorbic.Acid_DoseF  \
# 0             -4.076795         -2.297425            -4.134931
# 1             -1.578264          2.204654            -0.132025
# 2             -0.062048          5.429371            -0.614219
# 3              3.069499          0.969638             0.928592
# 4             -0.173469          2.009814            -1.716690
# ...                 ...               ...                  ...
# 1210          -0.299505         -2.711028             0.581082
# 1211          -0.988443         -7.432151             0.124789
# 1212          -1.486218          2.701207            -0.356241
# 1213           3.428898          0.681432            -0.415179
# 1214          -2.443233         -0.979876             0.320442
#
#       Bosentan_DoseB  Busulfan_DoseD  Carbamazepine_DoseC  Cetirizine_DoseD  \
# 0          -2.010770       -2.211001            -2.601455         -2.267580
# ...

# %%
teratox_commercial_pscore_per_drug_dose
# Out:
#       Amoxicillin_DoseF  Artesunate_DoseD  Ascorbic.Acid_DoseF  \
# 0             -4.076795         -2.297425            -4.134931
# 1             -1.578264          2.204654            -0.132025
# 2             -0.062048          5.429371            -0.614219
# 3              3.069499          0.969638             0.928592
# 4             -0.173469          2.009814            -1.716690
# ...                 ...               ...                  ...
# 1210          -0.299505         -2.711028             0.581082
# 1211          -0.988443         -7.432151             0.124789
# 1212          -1.486218          2.701207            -0.356241
# 1213           3.428898          0.681432            -0.415179
# 1214          -2.443233         -0.979876             0.320442
#
#       Bosentan_DoseB  Busulfan_DoseD  Carbamazepine_DoseC  Cetirizine_DoseD  \
# 0          -2.010770       -2.211001            -2.601455         -2.267580
# ...

# %%
teratox_commercial_pscore_per_drug_dose = pd.concat([teratox_commercial_pscore_per_drug_dose,teratox_commercial_pscore['NAME']], axis=1)
teratox_commercial_pscore_per_drug_dose
# Out:
#       Amoxicillin_DoseF  Artesunate_DoseD  Ascorbic.Acid_DoseF  \
# 0             -4.076795         -2.297425            -4.134931
# 1             -1.578264          2.204654            -0.132025
# 2             -0.062048          5.429371            -0.614219
# 3              3.069499          0.969638             0.928592
# 4             -0.173469          2.009814            -1.716690
# ...                 ...               ...                  ...
# 1210          -0.299505         -2.711028             0.581082
# 1211          -0.988443         -7.432151             0.124789
# 1212          -1.486218          2.701207            -0.356241
# 1213           3.428898          0.681432            -0.415179
# 1214          -2.443233         -0.979876             0.320442
#
#       Bosentan_DoseB  Busulfan_DoseD  Carbamazepine_DoseC  Cetirizine_DoseD  \
# 0          -2.010770       -2.211001            -2.601455         -2.267580
# ...

# %%
# !pip install xlrd

# %%
ranked_genes = pd.read_csv('res_MV.csv')
ranked_genes['TS'].abs().rank(ascending=False)
ranked_genes
# Out:
#       Unnamed: 0    genes          TS        SD
# 0              1     LEPR   52.618170  1.459384
# 1              2     EBF1   35.658950  1.237375
# 2              3   ATP2A2   34.615728  1.133350
# 3              4    ENPP1   32.711354  1.403608
# 4              5    WNT11   32.044909  1.249420
# ...          ...      ...         ...       ...
# 1210        1211     IRF7  -91.385284  1.153673
# 1211        1212   PIK3R3 -103.653738  0.803333
# 1212        1213    PTHLH -113.310863  1.494452
# 1213        1214    ATP7B -130.528097  0.948514
# 1214        1215  ALDH3A2 -140.257543  1.142372
#
# [1215 rows x 4 columns]

# %%
ranked_genes['genes'].to_list()[:10]
# Out:
# ['LEPR',
#  'EBF1',
#  'ATP2A2',
#  'ENPP1',
#  'WNT11',
#  'TP73',
#  'CASP3',
#  'NRF1',
#  'TIMP1',
#  'NRAS']

# %%
teratox_commercial_pscore_per_drug_dose_selected_genes = teratox_commercial_pscore_per_drug_dose.loc[teratox_commercial_pscore_per_drug_dose['NAME'].isin(ranked_genes['genes'].to_list()[:5])]
teratox_commercial_pscore_per_drug_dose_selected_genes
# Out:
#       Amoxicillin_DoseF  Artesunate_DoseD  Ascorbic.Acid_DoseF  \
# 161           -1.940200          1.783518            -1.926864
# 999           -2.082447         -2.642441            -2.543087
# 1002           0.766208         -0.494581            -0.957204
# 1008          -0.053309         -0.131141             1.589793
# 1105          -2.070976         -1.996041            -2.376929
#
#       Bosentan_DoseB  Busulfan_DoseD  Carbamazepine_DoseC  Cetirizine_DoseD  \
# 161         2.311217        0.709553            -4.246536         -1.130006
# 999        -1.387595       -1.144634            -0.049531         -0.709737
# 1002       -0.805522       -0.898809            -1.647735         -0.734401
# 1008       -0.432137        0.752819             2.766518          1.976045
# 1105       -1.519390       -1.952082             0.045785         -1.115916
#
#       Cyclopamine_DoseA  Cyproheptadine_DoseD  Dabrafenib_DoseD  ...  \
# ...

# %%
# !pip install -U scikit-learn
from sklearn.linear_model import ElasticNet


X = teratox_commercial_pscore_per_drug_dose_selected_genes.drop('NAME', axis=1).to_numpy()
y = teratox_commercial_phenodata_below_cyto_withoutSD["Teratogenicity"].to_numpy()
# Out:
# Requirement already up-to-date: scikit-learn in c:\users\user\anaconda_spyder\envs\wb\lib\site-packages (1.3.0)
# ...

# %%
X = np.transpose(X)

# %%
X.shape
# Out:
# (33, 5)

# %%
# from sklearn import tree 
# from sklearn.model_selection import train_test_split

# md = 14  # max depth
# print("Creating decision tree max_depth=" + str(md))
# model = tree.DecisionTreeClassifier(max_depth=md,random_state=4, class_weight='balanced')

# %%
# x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=7, random_state=4)

# %%
# x_train.shape

# %%
# model.fit(x_train, y_train)

# %%
# model.score(x_test, y_test)

# %%
#  model.score(x_train, y_train)

# %%
# y_pred = model.predict(x_test)

# %%
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier


# cv = LeaveOneOut()
# y_true, y_pred = list(), list()
# for train_ix, test_ix in cv.split(X):
# 	# split data
# 	X_train, X_test = X[train_ix, :], X[test_ix, :]
# 	y_train, y_test = y[train_ix], y[test_ix]
# 	# fit model
# 	model = RandomForestClassifier(n_estimators=25,random_state=1,class_weight = 'balanced_subsample')
# 	model.fit(X_train, y_train)
# 	# evaluate model
# 	yhat = model.predict(X_test)
# 	# store
# 	y_true.append(y_test[0])
# 	y_pred.append(yhat[0])
# # calculate accuracy
# acc = accuracy_score(y_true, y_pred)
# print('Accuracy: %.3f' % acc)

# %%
from sklearn.metrics import classification_report
# print(classification_report(y_true, y_pred, target_names=['Positive','Negative']))

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report


from sklearn.datasets import make_circles, make_classification, make_moons
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier



names = [
    "Nearest Neighbors",
    "Linear SVM",
    "RBF SVM",
    "Gaussian Process",
    "Decision Tree",
    "Random Forest",
    "Neural Net",
    "AdaBoost",
    "Naive Bayes",
    "QDA",
]

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    MLPClassifier(alpha=1, max_iter=1000),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis(),
]

for name, clf in zip(names, classifiers):
    cv = LeaveOneOut()
    y_true, y_pred = list(), list()
    for train_ix, test_ix in cv.split(X):
        # split data
        X_train, X_test = X[train_ix, :], X[test_ix, :]
        y_train, y_test = y[train_ix], y[test_ix]
        # fit model
        model = clf
        # RandomForestClassifier(n_estimators=25,random_state=1,class_weight = 'balanced_subsample')
        model.fit(X_train, y_train)
        # evaluate model
        yhat = model.predict(X_test)
        # store
        y_true.append(y_test[0])
        y_pred.append(yhat[0])
    # calculate accuracy
    acc = accuracy_score(y_true, y_pred)
    print(name,'- Accuracy: %.3f' % acc)
    print(classification_report(y_true, y_pred, target_names=['Positive','Negative']))
    print('-------------------')
# Out:
# Nearest Neighbors - Accuracy: 0.424
#               precision    recall  f1-score   support
#
#     Positive       0.21      0.27      0.24        11
#     Negative       0.58      0.50      0.54        22
#
#     accuracy                           0.42        33
#    macro avg       0.40      0.39      0.39        33
# weighted avg       0.46      0.42      0.44        33
#
# -------------------
# Linear SVM - Accuracy: 0.636
#               precision    recall  f1-score   support
#
#     Positive       0.00      0.00      0.00        11
#     Negative       0.66      0.95      0.78        22
#
#     accuracy                           0.64        33
#    macro avg       0.33      0.48      0.39        33
# weighted avg       0.44      0.64      0.52        33
#
# -------------------
# RBF SVM - Accuracy: 0.636
#               precision    recall  f1-score   support
#
#     Positive       0.00      0.00      0.00        11
#     Negative       0.66      0.95      0.78        22
#
# ...
